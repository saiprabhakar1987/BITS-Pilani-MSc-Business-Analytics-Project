# %% [markdown]
# # Import Libraries
#
# ### Goal -   To apply Machine Learning (ML) techniques such as
# • ARIMA - Auto Regressive Moving Average - ok
# <br>• Support Vector Machines (SVM) -ok
# <br>• Random Forest - ok Two ways direct ,one step ahead implementation. Can be an underestimate of the projections
# <br>• Gradient Boosting Machine (GBM) - Similar to Random Forest
#
# <br><br>• Generalized Neural Network (GRNN) - To do

# %%
from pathlib import Path
from matplotlib import pyplot as plt

import pandas as pd
import numpy as np
import os
import matplotlib as mpl


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import Data

# %%
from google.colab import files
uploaded = files.upload()

# %% [raw]
# # In this code, we first load the wheat prices data as a Pandas DataFrame, and split it into training and testing sets. We then normalize the training and testing data using min-max scaling, which scales the data to the range of 0 to 1. We define an SVM model using the SVR() function from the sklearn library, and train it on the training data using the fit() method. We use the trained model to make predictions on the testing data using the predict() method, and scale the predicted targets back to their original range using the inverse_transform() method of the scaler object. Finally, we calculate the root mean squared error (RMSE) of the predictions as a measure of their accuracy.

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# set random seed for reproducibility
np.random.seed(42)

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 61.94704420001643

# %%
# Plot the actual and predicted values
plt.title('SVR - Wheat Price Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 127.39292476012797

# %%
# Plot the actual and predicted values
plt.title('SVR - Barley Price Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 96.0222363898354

# %%
# Plot the actual and predicted values
plt.title('SVR - Maize Price Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 994.3415957899106

# %%
# Plot the actual and predicted values
plt.title('SVR - Soyabean Price Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 2925050.4202804095

# %%
# Plot the actual and predicted values
plt.title('SVR - Wheat Volume Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 323437.29292412737

# %%
# Plot the actual and predicted values
plt.title('SVR - Maize Volume Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 50862.228763585495

# %%
# Plot the actual and predicted values
plt.title('SVR - Barley Volume Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# normalize the training and testing data using min-max scaling
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# define the SVM model and train it on the training data
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
train_inputs, train_targets = train_data_scaled[:-1], train_data_scaled[1:]
svr.fit(train_inputs, train_targets)

# use the trained model to make predictions on the testing data
test_inputs = test_data_scaled[:-1]
predicted_targets = svr.predict(test_inputs)

# scale the predicted targets back to their original range
predicted_targets = scaler.inverse_transform(predicted_targets.reshape(-1, 1)).flatten()

# calculate the root mean squared error (RMSE) of the predictions
actual_targets = test_data[1:].values
rmse = np.sqrt(mean_squared_error(actual_targets, predicted_targets))
print('RMSE:', rmse)
# Out:
# RMSE: 289630.4709424546

# %%
# Plot the actual and predicted values
plt.title('SVR - Soyabean Volume Prediction')
plt.plot(actual_targets, label='Actual')
plt.plot(predicted_targets, label='Predicted')
plt.legend()
plt.show()
